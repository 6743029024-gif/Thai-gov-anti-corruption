# %% [markdown]
# <a href="https://colab.research.google.com/github/6743029024-gif/Thai-gov-anti-corruption/blob/main/week-00-setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

BASE = '/content/drive/MyDrive/data-analysis-lab'

for w in range(1, 13):
    d = f'{BASE}/week-{w:02d}'
    os.makedirs(f'{d}/data/raw', exist_ok=True)
    os.makedirs(f'{d}/data/clean', exist_ok=True)
    path = f'{d}/README.md'
    if not os.path.exists(path):
        with open(path, 'w', encoding='utf-8') as f:
            f.write(f"""# Week {w:02d}

**Question:**

**Who would act on the answer:**

**Data source:**

**Method:**

**Finding:**

**Limitation:**
""")

print('Done. Folders created at:', BASE)
# Out:
# Done. Folders created at: /content/drive/MyDrive/data-analysis-lab

# %%
import pandas as pd
print(pd.__version__)
print(sorted(os.listdir(BASE)))
# Out:
# 2.2.2
# ['week-01', 'week-02', 'week-03', 'week-04', 'week-05', 'week-06', 'week-07', 'week-08', 'week-09', 'week-10', 'week-11', 'week-12']
